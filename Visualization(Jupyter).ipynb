# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use("ggplot")

# %%
###Car 1

df=pd.DataFrame()

df["NEH"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["Random"]=[7038.0, 7038.0, 7038.0, 7057.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7059.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7048.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7057.0, 7038.0, 7048.0, 7038.0, 7038.0]

df["initial"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["P=5"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["P=10"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["P=20"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["P=50"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["P=100"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["Pc=0"]=[8220.0, 7938.0, 7655.0, 7829.0, 7590.0, 7792.0, 7828.0, 7472.0, 7991.0, 7689.0, 7626.0, 7700.0, 8098.0, 7272.0, 7565.0, 7844.0, 7685.0, 7740.0, 7626.0, 7677.0, 8435.0, 7708.0, 8243.0, 7797.0, 7730.0, 7804.0, 7885.0, 8277.0, 7685.0, 7573.0]

df["Pc=0.5"]=[7648.0, 8171.0, 7589.0, 7890.0, 7817.0, 8092.0, 7971.0, 8130.0, 7612.0, 8206.0, 7542.0, 7732.0, 7677.0, 7687.0, 7652.0, 7847.0, 7706.0, 7548.0, 7781.0, 7797.0, 7843.0, 7779.0, 7563.0, 7593.0, 7820.0, 7530.0, 7803.0, 7753.0, 7768.0, 7444.0]

df["Pc=0.7"]=[7689.0, 7899.0, 7689.0, 7892.0, 8009.0, 7689.0, 7834.0, 7974.0, 7276.0, 7904.0, 7618.0, 7726.0, 7788.0, 7816.0, 8125.0, 7961.0, 7974.0, 7965.0, 7689.0, 7554.0, 7789.0, 7689.0, 7803.0, 7707.0, 7881.0, 7230.0, 7697.0, 8254.0, 7709.0, 7828.0]

df["Pc=0.9"]=[8098.0, 7502.0, 7689.0, 7832.0, 7689.0, 7276.0, 7643.0, 7370.0, 7519.0, 7677.0, 7978.0, 7935.0, 7760.0, 7839.0, 7793.0, 7472.0, 7689.0, 7712.0, 7828.0, 7853.0, 7229.0, 7554.0, 7358.0, 7712.0, 7894.0, 7491.0, 7566.0, 8062.0, 7880.0, 7802.0]

df["Pm=0"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["Pm=0.2"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["Pm=0.4"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["Pm=0.6"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["Pm=1"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["D=0"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["D=0.5"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]

df["D=1"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]


plt.figure(figsize=(16,5))


df.boxplot()
plt.title('Car 1', size=20)
plt.xlabel("Different Parameters", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
###Car 2 

df=pd.DataFrame()

df["NEH"]=[8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0]

df["Random"]=[8688.0, 8744.0, 8754.0, 8505.0, 8505.0, 8715.0, 8754.0, 8715.0, 8728.0, 8715.0, 8715.0, 8730.0, 8754.0, 8728.0, 8817.0, 8715.0, 8505.0, 8715.0, 8715.0, 8505.0, 8688.0, 8715.0, 8570.0, 8570.0, 8715.0, 8742.0, 8505.0, 8505.0, 8715.0, 8715.0]

df["initial"]=[8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8754.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8570.0, 8773.0, 8773.0, 8773.0, 8773.0]

df["P=5"]=[8744.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 
281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0]

df["Pm=0.2"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1272.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1278.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0]

df["Pm=0.4"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1262.0, 1281.0, 1281.0, 1280.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1266.0, 1281.0, 1281.0, 1281.0]

df["Pm=0.6"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1279.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0]

df["Pm=1"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1266.0]

df["D=0"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0]

df["D=0.5"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0]

df["D=1"]=[1281.0, 1281.0, 1281.0, 1280.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1262.0, 1281.0, 1281.0]

plt.figure(figsize=(16,5))

df.boxplot()
plt.title('Car 3', size=20)
plt.xlabel("Different Parameters", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
###Car 4

df=pd.DataFrame()

df["NEH"]=[1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00]

df["Random"]=[1671., 1686., 1697., 1682., 1684., 1677., 1681., 1675., 1669.,1685., 1697., 1697., 1679., 1702., 1664., 1697., 1689., 1680., 1682., 1677., 1673., 1698., 1671., 1670., 1670., 1696., 1695., 1680., 1665., 1701.]

df["initial"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["P=5"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["P=10"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["P=20"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["P=50"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["P=100"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["Pc=0"]=[1806.0, 1797.0, 1838.0, 1789.0, 1801.0, 1832.0, 1902.0, 1855.0, 1759.0, 1804.0, 1905.0, 1843.0, 1818.0, 1795.0, 1834.0, 1853.0, 1753.0, 1786.0, 1849.0, 1773.0, 1841.0, 1790.0, 1866.0, 1862.0, 1759.0, 1785.0, 1815.0, 1816.0, 1804.0, 1870.0]

df["Pc=0.5"]=[1821.0, 1844.0, 1724.0, 1797.0, 1788.0, 1764.0, 1791.0, 1738.0, 1768.0, 1832.0, 1884.0, 1828.0, 1851.0, 1716.0, 1782.0, 1842.0, 1849.0, 1818.0, 1804.0, 1773.0, 1834.0, 1843.0, 1818.0, 1789.0, 1816.0, 1845.0, 1802.0, 1773.0, 1743.0, 1823.0]

df["Pc=0.7"]=[1807.0, 1860.0, 1890.0, 1783.0, 1815.0, 1802.0, 1772.0, 1791.0, 1796.0, 1828.0, 1710.0, 1790.0, 1783.0, 1808.0, 1856.0, 1757.0, 1804.0, 1740.0, 1767.0, 1794.0, 1767.0, 1808.0, 1754.0, 1778.0, 1772.0, 1791.0, 1791.0, 1854.0, 1831.0, 1855.0]

df["Pc=0.9"]=[1798.0, 1803.0, 1821.0, 1762.0, 1838.0, 1859.0, 1775.0, 1810.0, 1824.0, 1765.0, 1837.0, 1824.0, 1863.0, 1829.0, 1870.0, 1835.0, 1759.0, 1797.0, 1718.0, 1795.0, 1810.0, 1805.0, 1837.0, 1853.0, 1804.0, 1778.0, 1816.0, 1825.0, 1807.0, 1761.0]

df["Pm=0"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["Pm=0.2"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["Pm=0.4"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["Pm=0.6"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["Pm=1"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["D=0"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["D=0.5"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df["D=1"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]


plt.figure(figsize=(16,5))

df.boxplot()
plt.title('Car 4', size=20)
plt.xlabel("Different Parameters", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
###Car 5

df=pd.DataFrame()

df["NEH"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["Random"]=[2345., 2352., 2351., 2325., 2355., 2359., 2362., 2269., 2347., 2359., 2363., 2353., 2356., 2336., 2360., 2351., 2356., 2331., 2353., 2353., 2376., 2325., 2363., 2339., 2352., 2320., 2367., 2361., 2337., 2360.]

df["initial"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["P=5"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2181., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.]

df["P=10"]=[2185., 2185., 2185., 2184., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2184., 2185., 2185., 2185.]

df["P=20"]=[2185., 2185., 2185., 2185., 2184., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2181., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["P=50"]=[2185., 2185., 2185., 2185., 2185., 2183., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["P=100"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["Pc=0"]=[2499., 2479., 2534., 2510., 2548., 2510., 2526., 2524., 2544.,2517., 2479., 2493., 2518., 2518., 2554., 2469., 2445., 2506.,2470., 2546., 2574., 2521., 2573., 2545., 2493., 2520., 2475.,2493., 2505., 2541.]

df["Pc=0.5"]=[2469., 2533., 2511., 2494., 2501., 2525., 2545., 2512., 2543.,2427., 2490., 2482., 2583., 2451., 2477., 2522., 2494., 2482.,2571., 2449., 2471., 2508., 2536., 2456., 2565., 2516., 2535., 2458., 2473., 2441.]

df["Pc=0.7"]=[2430., 2498., 2516., 2417., 2540., 2509., 2479., 2480., 2423.,2533., 2499., 2399., 2460., 2477., 2552., 2547., 2502., 2520.,2483., 2533., 2500., 2520., 2577., 2493., 2474., 2538., 2542., 2461., 2516., 2495.]

df["Pc=0.9"]=[2415., 2482., 2510., 2447., 2496., 2514., 2504., 2490., 2492.,2556., 2475., 2486., 2476., 2471., 2493., 2499., 2452., 2510.,2410., 2449., 2545., 2481., 2494., 2534., 2476., 2512., 2475.,2533., 2468., 2560.]

df["Pm=0"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2184.,2185., 2185., 2185.]

df["Pm=0.2"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["Pm=0.4"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2182., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2180., 2185., 2185., 2185.,2185., 2185., 2185.]

df["Pm=0.6"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["Pm=1"]=[2185., 2167., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["D=0"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185.,2185., 2185., 2184., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185.,2185., 2185., 2185.]

df["D=0.5"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2184.,2184., 2185., 2185.]

df["D=1"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2184., 2185., 2185.,2185., 2185., 2185.]

plt.figure(figsize=(16,5))

df.boxplot()
plt.title('Car 5', size=20)
plt.xlabel("Different Parameters", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
#boxplot 3 alg

# %%
#car5
df=pd.DataFrame()
df["NEH"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df["Random"]=[2345., 2352., 2351., 2325., 2355., 2359., 2362., 2269., 2347., 2359., 2363., 2353., 2356., 2336., 2360., 2351., 2356., 2331., 2353., 2353., 2376., 2325., 2363., 2339., 2352., 2320., 2367., 2361., 2337., 2360.]

df["Genetic"]=[2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185., 2185.,2185., 2185., 2185.]

df.boxplot()
plt.title('Car 5', size=18)
plt.xlabel("Method used", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
df=pd.DataFrame()

df["NEH"]=[1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00,1626.00]
df["Random"]=[1671., 1686., 1697., 1682., 1684., 1677., 1681., 1675., 1669.,1685., 1697., 1697., 1679., 1702., 1664., 1697., 1689., 1680., 1682., 1677., 1673., 1698., 1671., 1670., 1670., 1696., 1695., 1680., 1665., 1701.]
df["Genetic"]=[1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0, 1626.0]

df.boxplot()
plt.title('Car 4', size=20)
plt.xlabel("Method used", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
df=pd.DataFrame()

df["NEH"]=df["NEH"]=[1281.00,1281.0,1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00,1281.0, 1281.00,1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00, 1281.00]             
df["Random"]=df["Random"]=[1281.0, 1298.0, 1294.0, 1286.0, 1304.0, 1299.0, 1279.0, 1299.0, 1287.0, 1299.0, 1297.0, 1283.0, 1285.0, 1292.0, 1273.0, 1287.0, 1311.0, 1290.0, 1295.0, 1283.0, 1298.0, 1306.0, 1291.0, 1300.0, 1271.0, 1275.0, 1300.0, 1298.0, 1302.0, 1303.0]
df["Genetic"]=[1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1266.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1281.0, 1280.0, 1281.0, 1266.0, 1281.0, 1281.0, 1281.0, 1281.0]

df.boxplot()
plt.title('Car 3', size=20)
plt.xlabel("Method used", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
df=pd.DataFrame()
df["NEH"]=[8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0]
df["Random"]=[8688.0, 8744.0, 8754.0, 8505.0, 8505.0, 8715.0, 8754.0, 8715.0, 8728.0, 8715.0, 8715.0, 8730.0, 8754.0, 8728.0, 8817.0, 8715.0, 8505.0, 8715.0, 8715.0, 8505.0, 8688.0, 8715.0, 8570.0, 8570.0, 8715.0, 8742.0, 8505.0, 8505.0, 8715.0, 8715.0]
df["Genetic"]=[8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8754.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8773.0, 8570.0, 8773.0, 8773.0, 8773.0, 8773.0]

df.boxplot()
plt.title('Car 2', size=20)
plt.xlabel("Method used", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()

# %%
df=pd.DataFrame()

df["NEH"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]
df["Random"]=[7038.0, 7038.0, 7038.0, 7057.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7059.0, 7038.0, 7038.0, 7095.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7048.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7057.0, 7038.0, 7048.0, 7038.0, 7038.0]
df["Genetic"]=[7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0, 7038.0]
df.boxplot()
plt.title('Car 1', size=20)
plt.xlabel("Method used", size=15)
plt.ylabel("Makespan Values", size=15)

plt.show()
